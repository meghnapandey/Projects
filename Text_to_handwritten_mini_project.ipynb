# %%
pip install pywhatkit
# Out:
# ...
#      |████████████████████████████████| 55 kB 674 kB/s eta 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 292 kB 586 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 53 kB 664 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 143 kB 576 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 273 kB 840 kB/s eta 0:00:01
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35193 sha256=aa0728e879dd19d31dd60b0a55645493c0b90b2946d712f0e267072890975cdd
#   Stored in directory: /Users/apple/Library/Caches/pip/wheels/4d/0d/6a/4258cb741835ea9ce7897652ae88272d3baf5cb1944c1984aa
# ...

# %%
import pywhatkit as pyt

# %% [markdown]
# # To convert the given text into handwritten

# %%
pyt.text_to_handwriting("My name is Meghna Pandey.I'm a technology enthusiat.")

# %% [markdown]
# # To open Youtube and play the given song

# %%
pyt.playonyt("Shape of you")
# Out:
# 'https://www.youtube.com/watch?v=JGwWNGJdvx8'
